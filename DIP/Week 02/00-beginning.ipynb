# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> View the location of the interpreter on your computer</div>

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %% [markdown]
# ##  <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> View the project's working folder or working directory</div>

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
import cv2
import numpy as np
import matplotlib

# %%
print (cv2.__version__)
# Out:
# 4.13.0
